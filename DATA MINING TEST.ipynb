# %% [markdown]
# # Section 1 - Data Mining

# %%
import pandas as pd
import numpy as np

# import visualization libraries
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
import matplotlib as pyplot
# %matplotlib inline

# %% [markdown]
# #### Fetching Monthly Data

# %%
january_df = pd.read_csv('.\January.csv')
february_df = pd.read_csv('.\February.csv')
march_df = pd.read_csv('.\March.csv')
april_df = pd.read_csv('.\April.csv')
may_df = pd.read_csv('.\May.csv')
june_df = pd.read_csv('.\June.csv')
july_df = pd.read_csv('.\July.csv')
august_df = pd.read_csv('.\August.csv')
september_df = pd.read_csv('.\September.csv')
october_df = pd.read_csv('.\October.csv')
november_df = pd.read_csv('./November.csv', encoding='utf-8',delimiter=',')
december_df = pd.read_csv('.\December.csv')

# %%
january_df.columns
# Out:
# Index(['YEAR', 'MONTH', 'OP_UNIQUE_CARRIER', 'TAIL_NUM', 'OP_CARRIER_FL_NUM',
#        'ORIGIN_CITY_NAME', 'ORIGIN_STATE_NM', 'DEST', 'DEST_CITY_NAME',
#        'DEST_STATE_ABR', 'DEST_STATE_NM', 'DEP_TIME', 'DEP_DELAY', 'DEP_DEL15',
#        'DEP_DELAY_GROUP', 'TAXI_OUT', 'TAXI_IN', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'FLIGHTS', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'DIV_AIRPORT_LANDINGS', 'Unnamed: 33'],
#       dtype='object')

# %%
february_df.columns
# Out:
# Index(['YEAR', 'MONTH', 'OP_UNIQUE_CARRIER', 'TAIL_NUM', 'OP_CARRIER_FL_NUM',
#        'ORIGIN_CITY_NAME', 'ORIGIN_STATE_NM', 'DEST', 'DEST_CITY_NAME',
#        'DEST_STATE_ABR', 'DEST_STATE_NM', 'DEP_TIME', 'DEP_DELAY', 'DEP_DEL15',
#        'DEP_DELAY_GROUP', 'TAXI_OUT', 'TAXI_IN', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'FLIGHTS', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'DIV_AIRPORT_LANDINGS', 'Unnamed: 33'],
#       dtype='object')

# %%
february_df.head()
# Out:
#    YEAR  MONTH OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN_CITY_NAME  \
# 0  2019      2                AA   N989AN                210        Miami, FL
# 1  2019      2                AA   N346PR                210        Miami, FL
# 2  2019      2                AA   N872NN                210        Miami, FL
# 3  2019      2                AA   N316PF                210        Miami, FL
# 4  2019      2                AA   N855NN                210        Miami, FL
#
#   ORIGIN_STATE_NM DEST DEST_CITY_NAME DEST_STATE_ABR  ... AIR_TIME  FLIGHTS  \
# 0         Florida  PHX    Phoenix, AZ             AZ  ...    274.0      1.0
# 1         Florida  PHX    Phoenix, AZ             AZ  ...    298.0      1.0
# 2         Florida  PHX    Phoenix, AZ             AZ  ...    290.0      1.0
# 3         Florida  PHX    Phoenix, AZ             AZ  ...    298.0      1.0
# 4         Florida  PHX    Phoenix, AZ             AZ  ...    283.0      1.0
#
# ...

# %%
january_df.head()
# Out:
#    YEAR  MONTH OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN_CITY_NAME  \
# 0  2019      1                9E   N195PQ               5121    Knoxville, TN
# 1  2019      1                9E   N919XJ               5121    Knoxville, TN
# 2  2019      1                9E   N316PQ               5122      Atlanta, GA
# 3  2019      1                9E   N325PQ               5122      Atlanta, GA
# 4  2019      1                9E   N904XJ               5122      Atlanta, GA
#
#   ORIGIN_STATE_NM DEST   DEST_CITY_NAME DEST_STATE_ABR  ... AIR_TIME  FLIGHTS  \
# 0       Tennessee  ATL      Atlanta, GA             GA  ...     36.0      1.0
# 1       Tennessee  ATL      Atlanta, GA             GA  ...     38.0      1.0
# 2         Georgia  SGF  Springfield, MO             MO  ...     84.0      1.0
# 3         Georgia  SGF  Springfield, MO             MO  ...     85.0      1.0
# 4         Georgia  SGF  Springfield, MO             MO  ...     88.0      1.0
#
# ...

# %%
march_df.columns
# Out:
# Index(['YEAR', 'MONTH', 'OP_UNIQUE_CARRIER', 'TAIL_NUM', 'OP_CARRIER_FL_NUM',
#        'ORIGIN_CITY_NAME', 'ORIGIN_STATE_NM', 'DEST', 'DEST_CITY_NAME',
#        'DEST_STATE_ABR', 'DEST_STATE_NM', 'DEP_TIME', 'DEP_DELAY', 'DEP_DEL15',
#        'DEP_DELAY_GROUP', 'TAXI_OUT', 'TAXI_IN', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'FLIGHTS', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'DIV_AIRPORT_LANDINGS', 'Unnamed: 33'],
#       dtype='object')

# %% [markdown]
# ### For question 1. -->What airline had the most number of flights in the first quarter of 2019 ?
# - merging the first three months data

# %%
merge_df = pd.concat([january_df,february_df, march_df], axis = 0)
merge_df.head()
# Out:
#    YEAR  MONTH OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN_CITY_NAME  \
# 0  2019      1                9E   N195PQ               5121    Knoxville, TN
# 1  2019      1                9E   N919XJ               5121    Knoxville, TN
# 2  2019      1                9E   N316PQ               5122      Atlanta, GA
# 3  2019      1                9E   N325PQ               5122      Atlanta, GA
# 4  2019      1                9E   N904XJ               5122      Atlanta, GA
#
#   ORIGIN_STATE_NM DEST   DEST_CITY_NAME DEST_STATE_ABR  ... AIR_TIME  FLIGHTS  \
# 0       Tennessee  ATL      Atlanta, GA             GA  ...     36.0      1.0
# 1       Tennessee  ATL      Atlanta, GA             GA  ...     38.0      1.0
# 2         Georgia  SGF  Springfield, MO             MO  ...     84.0      1.0
# 3         Georgia  SGF  Springfield, MO             MO  ...     85.0      1.0
# 4         Georgia  SGF  Springfield, MO             MO  ...     88.0      1.0
#
# ...

# %%
merge_df.groupby('OP_UNIQUE_CARRIER')['FLIGHTS'].count().sort_values(ascending=True)
# Out:
# OP_UNIQUE_CARRIER
# HA     19689
# G4     24294
# F9     28242
# EV     37584
# NK     46030
# YV     53701
# 9E     60880
# AS     61466
# OH     69080
# B6     72768
# MQ     75751
# YX     76818
# UA    144288
# OO    194934
# DL    225381
# AA    228103
# WN    330225
# Name: FLIGHTS, dtype: int64

# %% [markdown]
# The above result shows the airline with the most number of travel in the first quarter of 2019 is __( "WN","Southwest Airlines Co.")__

# %% [markdown]
# ### For question 2. --> total number airline travles in the first half of 2019. We merge from april - june to the merge_df.¶
# - Using the flight field that holds number of flight, with pandas count function for this answer

# %%
half_2019_df = pd.concat([merge_df, april_df, may_df, june_df], axis = 0)

# %%
half_2019_df['FLIGHTS'].value_counts()
# Out:
# 1.0    3634338
# Name: FLIGHTS, dtype: int64

# %% [markdown]
# The total number of airline travels in the half of 2019 is __" 3634338"__

# %% [markdown]
# ### Question 3 --> What is the Total AirTime by all Airlines in May 2019?

# %%
may_df.head()
# Out:
#    YEAR  MONTH OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN_CITY_NAME  \
# 0  2019      5                YX   N732YX               3700    St. Louis, MO
# 1  2019      5                YX   N652RW               3701      Chicago, IL
# 2  2019      5                YX   N862RW               3702  Minneapolis, MN
# 3  2019      5                YX   N862RW               3703      Chicago, IL
# 4  2019      5                YX   N732YX               3705       Newark, NJ
#
#   ORIGIN_STATE_NM DEST      DEST_CITY_NAME DEST_STATE_ABR  ... AIR_TIME  \
# 0        Missouri  EWR          Newark, NJ             NJ  ...    117.0
# 1        Illinois  RDU  Raleigh/Durham, NC             NC  ...     89.0
# 2       Minnesota  ORD         Chicago, IL             IL  ...     54.0
# 3        Illinois  BNA       Nashville, TN             TN  ...     61.0
# 4      New Jersey  MCI     Kansas City, MO             MO  ...    157.0
#
# ...

# %%
# Using the pandas profiling statisctical report
may_df.describe()
# Out:
#            YEAR     MONTH  OP_CARRIER_FL_NUM       DEP_TIME      DEP_DELAY  \
# count  636390.0  636390.0      636390.000000  623910.000000  623907.000000
# mean     2019.0       5.0        2520.607865    1337.169324      12.088218
# std         0.0       0.0        1806.636283     510.307018      49.101822
# min      2019.0       5.0           1.000000       1.000000     -46.000000
# 25%      2019.0       5.0         995.000000     913.000000      -5.000000
# 50%      2019.0       5.0        2095.000000    1328.000000      -2.000000
# 75%      2019.0       5.0        3837.000000    1750.000000       8.000000
# max      2019.0       5.0        7439.000000    2400.000000    1690.000000
#
#           DEP_DEL15  DEP_DELAY_GROUP       TAXI_OUT        TAXI_IN  \
# count  623907.00000    623907.000000  623438.000000  623166.000000
# mean        0.19964         0.160325      17.022256       7.715384
# std         0.39973         2.371038       9.674793       6.395810
# ...

# %% [markdown]
#  ###### Given the profiling reports above, the total Airtime by all airlines in the month of may is given as ["621339.000000"] in minutes.

# %%
# total airtime travel in hours
total_airtime_in_min = 621339.000000
hourly_airtime = (total_airtime_in_min / 60)

# %%
print(hourly_airtime)
# Out:
# 10355.65

# %% [markdown]
# Total airtime in __hours__ is __10355.65-hours__

# %% [markdown]
# ### For question 4 --> What city do you consider as the busiest city in April 2019 ?

# %%
april_df.head()
# Out:
#    YEAR  MONTH OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN_CITY_NAME  \
# 0  2019      4                NK   N646NK                779     New York, NY
# 1  2019      4                NK   N615NK                779     New York, NY
# 2  2019      4                NK   N633NK                779     New York, NY
# 3  2019      4                NK   N655NK                779     New York, NY
# 4  2019      4                NK   N605NK                779     New York, NY
#
#   ORIGIN_STATE_NM DEST       DEST_CITY_NAME DEST_STATE_ABR  ... AIR_TIME  \
# 0        New York  FLL  Fort Lauderdale, FL             FL  ...    146.0
# 1        New York  FLL  Fort Lauderdale, FL             FL  ...    141.0
# 2        New York  FLL  Fort Lauderdale, FL             FL  ...    148.0
# 3        New York  FLL  Fort Lauderdale, FL             FL  ...    164.0
# 4        New York  FLL  Fort Lauderdale, FL             FL  ...    159.0
#
# ...

# %% [markdown]
# A busy city can be attributed to the city having the most __flight activities__ in the region, owing to the greater number of people traveling.

# %%
april_df.groupby('ORIGIN_CITY_NAME')['FLIGHTS'].count().sort_values(ascending=False)
# Out:
# ORIGIN_CITY_NAME
# Chicago, IL              34396
# Atlanta, GA              32940
# New York, NY             25094
# Dallas/Fort Worth, TX    23933
# Houston, TX              19936
#                          ...
# Ogden, UT                    9
# Adak Island, AK              8
# Branson, MO                  8
# Hayden, CO                   2
# Gunnison, CO                 1
# Name: FLIGHTS, Length: 344, dtype: int64

# %%
april_df['ORIGIN_CITY_NAME'].value_counts().plot(kind='barh',
                                                        color=list('rgbkymc'),
                                                            alpha=0.7,figsize=(20,45))
plt.show()

# %% [markdown]
# ##### Chicago, IL  seem the busiest city in April 2019

# %% [markdown]
# ### For question 5 -->What airline covered the most distance in June 2019 ?

# %%
june_df.head()
# Out:
#    YEAR  MONTH OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN_CITY_NAME  \
# 0  2019      6                B6   N929JB                620    San Diego, CA
# 1  2019      6                B6   N981JT                623     New York, NY
# 2  2019      6                B6   N969JT                624  Los Angeles, CA
# 3  2019      6                B6   N339JB                626    Baltimore, MD
# 4  2019      6                B6   N997JL                629      Orlando, FL
#
#   ORIGIN_STATE_NM DEST   DEST_CITY_NAME DEST_STATE_ABR  ... AIR_TIME  FLIGHTS  \
# 0      California  BOS       Boston, MA             MA  ...    296.0      1.0
# 1        New York  LAX  Los Angeles, CA             CA  ...    343.0      1.0
# 2      California  JFK     New York, NY             NY  ...    300.0      1.0
# 3        Maryland  BOS       Boston, MA             MA  ...     59.0      1.0
# 4         Florida  BQN    Aguadilla, PR             PR  ...    127.0      1.0
#
# ...

# %%
june_df.columns
# Out:
# Index(['YEAR', 'MONTH', 'OP_UNIQUE_CARRIER', 'TAIL_NUM', 'OP_CARRIER_FL_NUM',
#        'ORIGIN_CITY_NAME', 'ORIGIN_STATE_NM', 'DEST', 'DEST_CITY_NAME',
#        'DEST_STATE_ABR', 'DEST_STATE_NM', 'DEP_TIME', 'DEP_DELAY', 'DEP_DEL15',
#        'DEP_DELAY_GROUP', 'TAXI_OUT', 'TAXI_IN', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'FLIGHTS', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'DIV_AIRPORT_LANDINGS', 'Unnamed: 33'],
#       dtype='object')

# %%
june_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636691 entries, 0 to 636690
# Data columns (total 34 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   YEAR                  636691 non-null  int64
#  1   MONTH                 636691 non-null  int64
#  2   OP_UNIQUE_CARRIER     636691 non-null  object
#  3   TAIL_NUM              635337 non-null  object
#  4   OP_CARRIER_FL_NUM     636691 non-null  int64
#  5   ORIGIN_CITY_NAME      636691 non-null  object
#  6   ORIGIN_STATE_NM       636691 non-null  object
#  7   DEST                  636691 non-null  object
#  8   DEST_CITY_NAME        636691 non-null  object
#  9   DEST_STATE_ABR        636691 non-null  object
#  10  DEST_STATE_NM         636691 non-null  object
#  11  DEP_TIME              624045 non-null  float64
#  12  DEP_DELAY             624043 non-null  float64
#  13  DEP_DEL15             624043 non-null  float64
# ...

# %%
dis_covered = june_df.loc[:,['OP_UNIQUE_CARRIER','DISTANCE']]

# %%
plt.figure(figsize=(8,15))
sns.barplot(x='DISTANCE',y='OP_UNIQUE_CARRIER', data= dis_covered)
plt.title("Airline That Covered The Most Distance In June 2019")
plt.show()

# %% [markdown]
# ###### The above result shows in 2019 AS("Alaska Airlines Inc") covered the most distance in 2019.

# %% [markdown]
# ### For question 6 -->What is the Tail Number of the aircraft that covered the most distance in Q2 of 2019 ? (5 Points)

# %%
## merging the two dataframes
Q2_df = pd.concat([april_df,june_df], axis=0)

# %%
Q2_df.head()
# Out:
#    YEAR  MONTH OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN_CITY_NAME  \
# 0  2019      4                NK   N646NK                779     New York, NY
# 1  2019      4                NK   N615NK                779     New York, NY
# 2  2019      4                NK   N633NK                779     New York, NY
# 3  2019      4                NK   N655NK                779     New York, NY
# 4  2019      4                NK   N605NK                779     New York, NY
#
#   ORIGIN_STATE_NM DEST       DEST_CITY_NAME DEST_STATE_ABR  ... AIR_TIME  \
# 0        New York  FLL  Fort Lauderdale, FL             FL  ...    146.0
# 1        New York  FLL  Fort Lauderdale, FL             FL  ...    141.0
# 2        New York  FLL  Fort Lauderdale, FL             FL  ...    148.0
# 3        New York  FLL  Fort Lauderdale, FL             FL  ...    164.0
# 4        New York  FLL  Fort Lauderdale, FL             FL  ...    159.0
#
# ...

# %%
Q2_df.columns
# Out:
# Index(['YEAR', 'MONTH', 'OP_UNIQUE_CARRIER', 'TAIL_NUM', 'OP_CARRIER_FL_NUM',
#        'ORIGIN_CITY_NAME', 'ORIGIN_STATE_NM', 'DEST', 'DEST_CITY_NAME',
#        'DEST_STATE_ABR', 'DEST_STATE_NM', 'DEP_TIME', 'DEP_DELAY', 'DEP_DEL15',
#        'DEP_DELAY_GROUP', 'TAXI_OUT', 'TAXI_IN', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'FLIGHTS', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'DIV_AIRPORT_LANDINGS', 'Unnamed: 33'],
#       dtype='object')

# %%
Q2_df['TAIL_NUM'].unique
# Out:
# <bound method Series.unique of 0         N646NK
# 1         N615NK
# 2         N633NK
# 3         N655NK
# 4         N605NK
#            ...
# 636686    N737US
# 636687    N8001N
# 636688    N9023N
# 636689    N974AN
# 636690    N4032T
# Name: TAIL_NUM, Length: 1248714, dtype: object>

# %%
Q2_df['DISTANCE'].unique
# Out:
# <bound method Series.unique of 0         1076.0
# 1         1076.0
# 2         1076.0
# 3         1076.0
# 4         1076.0
#            ...
# 636686     296.0
# 636687     296.0
# 636688     296.0
# 636689     296.0
# 636690     296.0
# Name: DISTANCE, Length: 1248714, dtype: float64>

# %%
Q2_df.describe()
# Out:
#             YEAR         MONTH  OP_CARRIER_FL_NUM      DEP_TIME     DEP_DELAY  \
# count  1248714.0  1.248714e+06       1.248714e+06  1.221931e+06  1.221922e+06
# mean      2019.0  5.019755e+00       2.558082e+03  1.337839e+03  1.333298e+01
# std          0.0  9.998053e-01       1.809588e+03  5.142936e+02  5.165195e+01
# min       2019.0  4.000000e+00       1.000000e+00  1.000000e+00 -8.200000e+01
# 25%       2019.0  4.000000e+00       1.027000e+03  9.110000e+02 -5.000000e+00
# 50%       2019.0  6.000000e+00       2.151000e+03  1.328000e+03 -2.000000e+00
# 75%       2019.0  6.000000e+00       3.898000e+03  1.752000e+03  9.000000e+00
# max       2019.0  6.000000e+00       7.933000e+03  2.400000e+03  2.079000e+03
#
#           DEP_DEL15  DEP_DELAY_GROUP      TAXI_OUT       TAXI_IN  \
# count  1.221922e+06     1.221922e+06  1.221125e+06  1.220574e+06
# mean   2.115176e-01     2.316171e-01  1.720652e+01  7.756761e+00
# std    4.083847e-01     2.453666e+00  9.947588e+00  6.378768e+00
# ...

# %%
grouped_Q2 = Q2_df.loc[:,['TAIL_NUM','DISTANCE']]

# %%
grouped_Q2_sort=grouped_Q2[(grouped_Q2.DISTANCE >= 5095)] #& (grouped_Q2.DISTANCE <= 5.095000e+04 )]
grouped_Q2_sort
# Out:
#        TAIL_NUM  DISTANCE
# 414751   N382HA    5095.0
# 414752   N395HA    5095.0
# 414753   N379HA    5095.0
# 414754   N370HA    5095.0
# 414755   N361HA    5095.0
# ...         ...       ...
# 507121   N379HA    5095.0
# 507122   N361HA    5095.0
# 507123   N382HA    5095.0
# 507124   N370HA    5095.0
# 507125   N396HA    5095.0
#
# [92 rows x 2 columns]

# %%
"""
In the above cell it shows we have about 92 rows containing different flight tail_number that covered the
same distance. Applying the pandas sort function to get the value value of tail_num in descending order.
"""
grouped_Q2_sort.sort_values(by='DISTANCE',ascending=False)
# Out:
#        TAIL_NUM  DISTANCE
# 414751   N382HA    5095.0
# 507092   N393HA    5095.0
# 507101   N386HA    5095.0
# 507100   N392HA    5095.0
# 507099   N370HA    5095.0
# ...         ...       ...
# 414779   N392HA    5095.0
# 414778   N383HA    5095.0
# 414777   N382HA    5095.0
# 414776   N389HA    5095.0
# 507125   N396HA    5095.0
#
# [92 rows x 2 columns]

# %% [markdown]
# Following the sort by descending order we can say the flight TAIL_NUM that covered the most distance is __N382HA__

# %% [markdown]
# ### For question 7 -->Which state recorded the most delays in the 2nd Quarter of 2019

# %%
Q2_df.head()
# Out:
#    YEAR  MONTH OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN_CITY_NAME  \
# 0  2019      4                NK   N646NK                779     New York, NY
# 1  2019      4                NK   N615NK                779     New York, NY
# 2  2019      4                NK   N633NK                779     New York, NY
# 3  2019      4                NK   N655NK                779     New York, NY
# 4  2019      4                NK   N605NK                779     New York, NY
#
#   ORIGIN_STATE_NM DEST       DEST_CITY_NAME DEST_STATE_ABR  ... AIR_TIME  \
# 0        New York  FLL  Fort Lauderdale, FL             FL  ...    146.0
# 1        New York  FLL  Fort Lauderdale, FL             FL  ...    141.0
# 2        New York  FLL  Fort Lauderdale, FL             FL  ...    148.0
# 3        New York  FLL  Fort Lauderdale, FL             FL  ...    164.0
# 4        New York  FLL  Fort Lauderdale, FL             FL  ...    159.0
#
# ...

# %%
Q2_df.columns
# Out:
# Index(['YEAR', 'MONTH', 'OP_UNIQUE_CARRIER', 'TAIL_NUM', 'OP_CARRIER_FL_NUM',
#        'ORIGIN_CITY_NAME', 'ORIGIN_STATE_NM', 'DEST', 'DEST_CITY_NAME',
#        'DEST_STATE_ABR', 'DEST_STATE_NM', 'DEP_TIME', 'DEP_DELAY', 'DEP_DEL15',
#        'DEP_DELAY_GROUP', 'TAXI_OUT', 'TAXI_IN', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'FLIGHTS', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'DIV_AIRPORT_LANDINGS', 'Unnamed: 33'],
#       dtype='object')

# %% [markdown]
# ###### Using pandas groupby function to check the individual states and delay stats

# %%
#carrier delay stat by States
Q2_df.groupby('ORIGIN_STATE_NM').CARRIER_DELAY.sum().sort_values(ascending=False)
# Out:
# ORIGIN_STATE_NM
# Texas                                             729048.0
# California                                        487494.0
# Florida                                           485392.0
# Illinois                                          390405.0
# Georgia                                           348429.0
# New York                                          327656.0
# North Carolina                                    246501.0
# Colorado                                          235605.0
# Virginia                                          199104.0
# Michigan                                          162214.0
# Arizona                                           145021.0
# Massachusetts                                     133032.0
# Pennsylvania                                      131691.0
# New Jersey                                        130939.0
# Nevada                                            128723.0
# Tennessee                                         104535.0
# ...

# %%
 # weather delay stats by States
Q2_df.groupby('ORIGIN_STATE_NM').WEATHER_DELAY.sum().sort_values(ascending=False)
# Out:
# ORIGIN_STATE_NM
# Texas                                             212765.0
# Florida                                           134032.0
# Illinois                                           77032.0
# Georgia                                            74858.0
# North Carolina                                     73709.0
# Virginia                                           50130.0
# Colorado                                           48238.0
# New York                                           45181.0
# Minnesota                                          42590.0
# Michigan                                           30849.0
# New Jersey                                         17917.0
# Tennessee                                          17239.0
# Missouri                                           16569.0
# California                                         16064.0
# Kentucky                                           15991.0
# Pennsylvania                                       14704.0
# ...

# %%
# Nas delay stats by States
Q2_df.groupby('ORIGIN_STATE_NM').NAS_DELAY.sum().sort_values(ascending=False)
# Out:
# ORIGIN_STATE_NM
# Florida                                           501633.0
# Texas                                             457779.0
# New York                                          323652.0
# California                                        320798.0
# Illinois                                          314695.0
# Georgia                                           210374.0
# Virginia                                          208279.0
# North Carolina                                    203939.0
# Colorado                                          166845.0
# Pennsylvania                                      129199.0
# Michigan                                          120252.0
# New Jersey                                        117451.0
# Massachusetts                                     110197.0
# Ohio                                               99401.0
# Tennessee                                          99339.0
# Minnesota                                          93763.0
# ...

# %%
 # security delay stat by States
Q2_df.groupby('ORIGIN_STATE_NM').SECURITY_DELAY.sum().sort_values(ascending=False)
# Out:
# ORIGIN_STATE_NM
# Hawaii                                            6131.0
# California                                        4892.0
# Michigan                                          2997.0
# Florida                                           2682.0
# Minnesota                                         1993.0
# Texas                                             1855.0
# North Carolina                                    1637.0
# Nebraska                                          1116.0
# Maryland                                           921.0
# New York                                           883.0
# Georgia                                            828.0
# Colorado                                           810.0
# Pennsylvania                                       716.0
# Nevada                                             649.0
# Washington                                         564.0
# Illinois                                           545.0
# ...

# %%
# late aircraft delay stat
Q2_df.groupby('ORIGIN_STATE_NM').LATE_AIRCRAFT_DELAY.sum().sort_values(ascending=False)
# Out:
# ORIGIN_STATE_NM
# Texas                                             907561.0
# Florida                                           641499.0
# California                                        614712.0
# New York                                          576739.0
# Illinois                                          565591.0
# North Carolina                                    438784.0
# Colorado                                          380805.0
# Georgia                                           377317.0
# Virginia                                          315440.0
# New Jersey                                        284018.0
# Pennsylvania                                      200634.0
# Massachusetts                                     190153.0
# Arizona                                           166880.0
# Nevada                                            164903.0
# Tennessee                                         153585.0
# Michigan                                          140845.0
# ...

# %% [markdown]
# From the above statistics __"Texas"__ recorded the most delay in the second quarter of the year with about more than a million delay counts across the different delay categories

# %% [markdown]
# ### For question 8 -->What is the daily average Taxi-out time in New York in February 2019 ?

# %%
february_df.columns
# Out:
# Index(['YEAR', 'MONTH', 'OP_UNIQUE_CARRIER', 'TAIL_NUM', 'OP_CARRIER_FL_NUM',
#        'ORIGIN_CITY_NAME', 'ORIGIN_STATE_NM', 'DEST', 'DEST_CITY_NAME',
#        'DEST_STATE_ABR', 'DEST_STATE_NM', 'DEP_TIME', 'DEP_DELAY', 'DEP_DEL15',
#        'DEP_DELAY_GROUP', 'TAXI_OUT', 'TAXI_IN', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'FLIGHTS', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'DIV_AIRPORT_LANDINGS', 'Unnamed: 33'],
#       dtype='object')

# %%
february_df.head()
# Out:
#    YEAR  MONTH OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN_CITY_NAME  \
# 0  2019      2                AA   N989AN                210        Miami, FL
# 1  2019      2                AA   N346PR                210        Miami, FL
# 2  2019      2                AA   N872NN                210        Miami, FL
# 3  2019      2                AA   N316PF                210        Miami, FL
# 4  2019      2                AA   N855NN                210        Miami, FL
#
#   ORIGIN_STATE_NM DEST DEST_CITY_NAME DEST_STATE_ABR  ... AIR_TIME  FLIGHTS  \
# 0         Florida  PHX    Phoenix, AZ             AZ  ...    274.0      1.0
# 1         Florida  PHX    Phoenix, AZ             AZ  ...    298.0      1.0
# 2         Florida  PHX    Phoenix, AZ             AZ  ...    290.0      1.0
# 3         Florida  PHX    Phoenix, AZ             AZ  ...    298.0      1.0
# 4         Florida  PHX    Phoenix, AZ             AZ  ...    283.0      1.0
#
# ...

# %%
daily_taxi_outtime_NY = february_df[february_df['ORIGIN_STATE_NM']=='New York']
daily_taxi_outtime_NY['ORIGIN_STATE_NM'].head()
# Out:
# 490    New York
# 491    New York
# 492    New York
# 493    New York
# 494    New York
# Name: ORIGIN_STATE_NM, dtype: object

# %%
"""
Using python groupby and aggregate method function to extract the daily average taxi out time for NewYork 
State.
"""
average_daily_Tout_time_NY = daily_taxi_outtime_NY.groupby(['ORIGIN_STATE_NM']).agg({'TAXI_OUT':'mean'})

# %%
average_daily_Tout_time_NY
# Out:
#                   TAXI_OUT
# ORIGIN_STATE_NM
# New York         24.689727

# %% [markdown]
# The daily average Taxi out time in New York City in february 2019 is __24.689727__

# %% [markdown]
# ### For question 9 -->How many airlines with New York destinations were diverted in Q1 2019 ?

# %%
"""
merge_df is a variable that contains merged data for the first quarter of the year
"""
merge_df.head()
# Out:
#    YEAR  MONTH OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN_CITY_NAME  \
# 0  2019      1                9E   N195PQ               5121    Knoxville, TN
# 1  2019      1                9E   N919XJ               5121    Knoxville, TN
# 2  2019      1                9E   N316PQ               5122      Atlanta, GA
# 3  2019      1                9E   N325PQ               5122      Atlanta, GA
# 4  2019      1                9E   N904XJ               5122      Atlanta, GA
#
#   ORIGIN_STATE_NM DEST   DEST_CITY_NAME DEST_STATE_ABR  ... AIR_TIME  FLIGHTS  \
# 0       Tennessee  ATL      Atlanta, GA             GA  ...     36.0      1.0
# 1       Tennessee  ATL      Atlanta, GA             GA  ...     38.0      1.0
# 2         Georgia  SGF  Springfield, MO             MO  ...     84.0      1.0
# 3         Georgia  SGF  Springfield, MO             MO  ...     85.0      1.0
# 4         Georgia  SGF  Springfield, MO             MO  ...     88.0      1.0
#
# ...

# %%
merge_df.columns
# Out:
# Index(['YEAR', 'MONTH', 'OP_UNIQUE_CARRIER', 'TAIL_NUM', 'OP_CARRIER_FL_NUM',
#        'ORIGIN_CITY_NAME', 'ORIGIN_STATE_NM', 'DEST', 'DEST_CITY_NAME',
#        'DEST_STATE_ABR', 'DEST_STATE_NM', 'DEP_TIME', 'DEP_DELAY', 'DEP_DEL15',
#        'DEP_DELAY_GROUP', 'TAXI_OUT', 'TAXI_IN', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'FLIGHTS', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'DIV_AIRPORT_LANDINGS', 'Unnamed: 33'],
#       dtype='object')

# %%
merge_df['DIVERTED'].unique()
# Out:
# array([0., 1.])

# %%
merge_df['DIVERTED'].value_counts()
# Out:
# 0.0    1745327
# 1.0       3907
# Name: DIVERTED, dtype: int64

# %%
merge_df['DEST_CITY_NAME'].value_counts()
# Out:
# Chicago, IL              96936
# Atlanta, GA              93400
# New York, NY             72978
# Dallas/Fort Worth, TX    68674
# Houston, TX              58451
#                          ...
# Pago Pago, TT               27
# Owensboro, KY               27
# Adak Island, AK             26
# Ogden, UT                   25
# Everett, WA                  6
# Name: DEST_CITY_NAME, Length: 341, dtype: int64

# %% [markdown]
# The above information shows we have the total number of undiverted flight as __1745327__ and total number of diverted flight to be __3907__. Following the question to find the NewYork diverted flight, we use python pandas comparable operator for extracting the diverted values and creating a new column to filter out diverted flight by City

# %%
No_of_diverted=merge_df[merge_df['DIVERTED']==1.0]

# %%
No_of_diverted['DIVERTED'].head()
# Out:
# 572     1.0
# 3123    1.0
# 5433    1.0
# 5646    1.0
# 6523    1.0
# Name: DIVERTED, dtype: float64

# %%
diverted_NY_destination = No_of_diverted.loc[No_of_diverted['DEST_CITY_NAME']== 'New York, NY']
len(diverted_NY_destination)
# Out:
# 151

# %% [markdown]
# The above result shows __151__ Airlines with NewYork destination got diverted

# %% [markdown]
# ### For question 10 -->Which of these delays is more rampant in Washington in the first half of 2019?

# %%
"""
half_2019_df is the variable that holds the data for the first half of 2019.
"""

half_2019_df.head()
# Out:
#    YEAR  MONTH OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN_CITY_NAME  \
# 0  2019      1                9E   N195PQ               5121    Knoxville, TN
# 1  2019      1                9E   N919XJ               5121    Knoxville, TN
# 2  2019      1                9E   N316PQ               5122      Atlanta, GA
# 3  2019      1                9E   N325PQ               5122      Atlanta, GA
# 4  2019      1                9E   N904XJ               5122      Atlanta, GA
#
#   ORIGIN_STATE_NM DEST   DEST_CITY_NAME DEST_STATE_ABR  ... AIR_TIME  FLIGHTS  \
# 0       Tennessee  ATL      Atlanta, GA             GA  ...     36.0      1.0
# 1       Tennessee  ATL      Atlanta, GA             GA  ...     38.0      1.0
# 2         Georgia  SGF  Springfield, MO             MO  ...     84.0      1.0
# 3         Georgia  SGF  Springfield, MO             MO  ...     85.0      1.0
# 4         Georgia  SGF  Springfield, MO             MO  ...     88.0      1.0
#
# ...

# %%
half_2019_df.groupby('ORIGIN_STATE_NM').CARRIER_DELAY.sum().sort_values(ascending=False)

# %%
washington_delay_df = half_2019_df[half_2019_df['ORIGIN_STATE_NM']== 'Washington']

# %%
washington_delay_df['CARRIER_DELAY'].value_counts()
# Out:
# 0.0       7637
# 7.0        194
# 4.0        174
# 15.0       169
# 6.0        169
#           ...
# 292.0        1
# 1615.0       1
# 215.0        1
# 162.0        1
# 291.0        1
# Name: CARRIER_DELAY, Length: 328, dtype: int64

# %%
washington_delay_df['WEATHER_DELAY'].value_counts()
# Out:
# 0.0      12075
# 10.0        24
# 9.0         24
# 15.0        22
# 8.0         21
#          ...
# 164.0        1
# 373.0        1
# 125.0        1
# 339.0        1
# 247.0        1
# Name: WEATHER_DELAY, Length: 213, dtype: int64

# %%
washington_delay_df['NAS_DELAY'].value_counts()
# Out:
# 0.0      4649
# 15.0      407
# 16.0      358
# 17.0      311
# 1.0       301
#          ...
# 251.0       1
# 236.0       1
# 130.0       1
# 268.0       1
# 232.0       1
# Name: NAS_DELAY, Length: 258, dtype: int64

# %%
washington_delay_df['SECURITY_DELAY'].value_counts()
# Out:
# 0.0      12859
# 15.0         5
# 12.0         3
# 13.0         3
# 30.0         2
# 2.0          2
# 31.0         2
# 45.0         2
# 23.0         2
# 10.0         2
# 25.0         2
# 32.0         1
# 8.0          1
# 1.0          1
# 18.0         1
# 33.0         1
# 133.0        1
# 7.0          1
# 118.0        1
# 19.0         1
# 17.0         1
# 21.0         1
# 4.0          1
# 3.0          1
# 16.0         1
# 9.0          1
# 5.0          1
# 27.0         1
# 35.0         1
# Name: SECURITY_DELAY, dtype: int64

# %%
washington_delay_df['LATE_AIRCRAFT_DELAY'].value_counts()
# Out:
# 0.0      7741
# 15.0      155
# 19.0      150
# 16.0      140
# 17.0      138
#          ...
# 229.0       1
# 444.0       1
# 255.0       1
# 318.0       1
# 185.0       1
# Name: LATE_AIRCRAFT_DELAY, Length: 290, dtype: int64

# %% [markdown]
#  __CARRIER_DELAY__ from the above analysis is more rampant in washington in the first half of 2019

# %% [markdown]
# # Section 3- Data Visualization
# Analysis and charts on the distributions of Taxi-out time across States,Cities and Airlines as it affect fuel consumption

# %%
# using the data for first half of 2019
half_2019_df.head()
# Out:
#    YEAR  MONTH OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN_CITY_NAME  \
# 0  2019      1                9E   N195PQ               5121    Knoxville, TN
# 1  2019      1                9E   N919XJ               5121    Knoxville, TN
# 2  2019      1                9E   N316PQ               5122      Atlanta, GA
# 3  2019      1                9E   N325PQ               5122      Atlanta, GA
# 4  2019      1                9E   N904XJ               5122      Atlanta, GA
#
#   ORIGIN_STATE_NM DEST   DEST_CITY_NAME DEST_STATE_ABR  ... AIR_TIME  FLIGHTS  \
# 0       Tennessee  ATL      Atlanta, GA             GA  ...     36.0      1.0
# 1       Tennessee  ATL      Atlanta, GA             GA  ...     38.0      1.0
# 2         Georgia  SGF  Springfield, MO             MO  ...     84.0      1.0
# 3         Georgia  SGF  Springfield, MO             MO  ...     85.0      1.0
# 4         Georgia  SGF  Springfield, MO             MO  ...     88.0      1.0
#
# ...

# %%
taxi_out_time_analysis = half_2019_df.loc[:,['OP_UNIQUE_CARRIER','ORIGIN_CITY_NAME','ORIGIN_STATE_NM','TAXI_OUT']]  
taxi_out_time_analysis.head()
# Out:
#   OP_UNIQUE_CARRIER ORIGIN_CITY_NAME ORIGIN_STATE_NM  TAXI_OUT
# 0                9E    Knoxville, TN       Tennessee      30.0
# 1                9E    Knoxville, TN       Tennessee      35.0
# 2                9E      Atlanta, GA         Georgia      20.0
# 3                9E      Atlanta, GA         Georgia      16.0
# 4                9E      Atlanta, GA         Georgia      25.0

# %% [markdown]
# ### Analysis
# Firstly we perform statistical test analysis to check
# whether the __average Taxi-out time across Cities and State is similar or not__ using the __ANOVA__ test
#
# __ANOVA test statistics__--> This is analysis of variance test that can be thought of as a generalization of t-tests for more than two groups. Where the independent of t-test is used to compare the means of a condition between more than two groups.Performing ANOVA requires setting a Null and Alternate hypothesis.
#
# - Null hypothesis: There is no significant difference among the groups.
# - Alternate Hypothesis: There is a significant difference among the groups.
# Therefore, these hypothesis are evaluated based on p-value associated with F-statistics. When p-value is < 0.05, then we reject the Null hypothesis and accept the alternative hypothesis. Also when the p-value is > 0.05 we reject the alternative hypothesis and accept the null hypothesis,thereby going with the conclusion that the means of the groups are equal,hence there is no significant difference

# %% [markdown]
# ___Test Condition__:
#
# - __H0__: Average Taxi-out time across Cities or States is similar
# - __H1__: Not similar

# %%
# impport neccessary libraries for statistical analyses
import scipy.stats as stats
from math import sqrt

# %%
#For a quick generalization, we extract the first six features for analysis

top_5_city = taxi_out_time_analysis['ORIGIN_CITY_NAME'].value_counts()[:5]

# fetch the names of the top 5 city to be used for analysis
top_5_city_names = top_5_city.index
top_5_city_names
# Out:
# Index(['Chicago, IL', 'Atlanta, GA', 'New York, NY', 'Dallas/Fort Worth, TX',
#        'Houston, TX'],
#       dtype='object')

# %%
#create sample test with the above features
sample_test = taxi_out_time_analysis.loc[taxi_out_time_analysis['ORIGIN_CITY_NAME'].isin(top_5_city_names),['ORIGIN_CITY_NAME','TAXI_OUT']]
sample_test.head()
# Out:
#   ORIGIN_CITY_NAME  TAXI_OUT
# 2      Atlanta, GA      20.0
# 3      Atlanta, GA      16.0
# 4      Atlanta, GA      25.0
# 5      Atlanta, GA      18.0
# 6      Atlanta, GA      23.0

# %%
# drop any form of missing values in our sample data
sample_test.dropna(how='any', inplace=True)

# %%
# creating the individual five sample space from our sample test data
s1 = sample_test[sample_test['ORIGIN_CITY_NAME']== top_5_city_names[0]].TAXI_OUT
s2 = sample_test[sample_test['ORIGIN_CITY_NAME']== top_5_city_names[1]].TAXI_OUT
s3 = sample_test[sample_test['ORIGIN_CITY_NAME']== top_5_city_names[2]].TAXI_OUT
s4 = sample_test[sample_test['ORIGIN_CITY_NAME']== top_5_city_names[3]].TAXI_OUT
s5 = sample_test[sample_test['ORIGIN_CITY_NAME']== top_5_city_names[4]].TAXI_OUT

# %%
# test statistics
stats.f_oneway(s1,s2,s3,s4,s5)
# Out:
# F_onewayResult(statistic=22705.804382403647, pvalue=0.0)

# %% [markdown]
# The __ANOVA__ test result shows the __p-value__ is less than __0.05__, so therefore reject null hypothesis and conclude the avaerage Taxi-out time across the different cities and States are not the same

# %% [markdown]
# ### Chart

# %% [markdown]
# __Chart illustrating the Taxi Out time across cities and on the airlines__

# %%
plt.figure(figsize=(20,45))
sns.set_style('darkgrid')
sns.pointplot(x='TAXI_OUT', y='ORIGIN_CITY_NAME', data=taxi_out_time_analysis, 
              hue='OP_UNIQUE_CARRIER',join=False)
plt.xlabel('TAXI_OUT',{'fontsize' : 'large'})
plt.ylabel('ORIGIN_CITY_NAME', {'fontsize' : 'large'})
plt.title("Taxi Out Time Across cities And Airlines In The Half of 2019")
plt.savefig('chart.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# __Chart illustrating the Taxi Out time across states
# and on the airlines__

# %%
plt.figure(figsize=(20,45))
sns.set_style('darkgrid')
sns.pointplot(x='TAXI_OUT', y='ORIGIN_STATE_NM', data=taxi_out_time_analysis, 
              hue='OP_UNIQUE_CARRIER',join=False)
plt.xlabel('TAXI_OUT',{'fontsize' : 'large'})
plt.ylabel('ORIGIN_STATE_NAME', {'fontsize' : 'large'})
plt.title("Taxi Out Time Across States And Airlines In The Half of 2019")
plt.savefig('chart2.png', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Taxi Out Time Distribution Graph')
ax = sns.distplot(taxi_out_time_analysis['TAXI_OUT'], color='g')
# Out:
# C:\Users\Ebuka\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Summary Analysis
# The Anova test analysis carried out revealed that the taxi out time distributed across the States, cities and on the airlines are not similar, indicating there is a significance difference.
#
# __Findings__
#
# - Majority of the taxi out time across the states and cities fall between the range of 10-20 minutes with few outliers exceeding this range.
# - SkyWest Airlines had the largest fuek consumed across all the cities with about 157 minutes taxi out time in Mosinee city and also in Valparaiso city with about 75 minutes taxi out time.
# - Across the states, Alaska Airline had the most fuel consumed in North Dakota, followed by Delta Airline in Alabama.

# %% [markdown]
# ## Recommendation
# - With majority of the Airlines having a 20-minutes taxi out time, this can be set as a model benchmark across all he states, cities and on the Airlines to help minimize fuel consumption
# - Airlines across states and cities exceeding the 20-minutes benchmark should be investigated to ascertain the attributes of this anomaly.
